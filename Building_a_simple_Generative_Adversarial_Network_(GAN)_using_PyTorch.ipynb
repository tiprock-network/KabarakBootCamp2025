# %% [markdown]
# # Building a simple Generative Adversarial Network (GAN) using PyTorch

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Define a basic transform
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

# %%
train_dataset = datasets.CIFAR10(root='./data',\
              train=True, download=True, transform=transform)
dataloader = torch.utils.data.DataLoader(train_dataset, \
                                batch_size=32, shuffle=True)
# Out:
# 100%|██████████| 170M/170M [00:05<00:00, 29.7MB/s]

# %%
# Hyperparameters
latent_dim = 100
lr = 0.0002
beta1 = 0.5
beta2 = 0.999
num_epochs = 10

# %%
#the generator
# Define the generator
class Generator(nn.Module):
    def __init__(self, latent_dim):
        super(Generator, self).__init__()

        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128 * 8 * 8),
            nn.ReLU(),
            nn.Unflatten(1, (128, 8, 8)),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128, momentum=0.78),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64, momentum=0.78),
            nn.ReLU(),
            nn.Conv2d(64, 3, kernel_size=3, padding=1),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        return img

# %%
# the discriminator
# Define the discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
        nn.Conv2d(3, 32, kernel_size=3, stride=2, padding=1),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1),
        nn.ZeroPad2d((0, 1, 0, 1)),
        nn.BatchNorm2d(64, momentum=0.82),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Conv2d(64, 128, kernel_size=3, stride=2, padding=1),
        nn.BatchNorm2d(128, momentum=0.82),
        nn.LeakyReLU(0.2),
        nn.Dropout(0.25),
        nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1),
        nn.BatchNorm2d(256, momentum=0.8),
        nn.LeakyReLU(0.25),
        nn.Dropout(0.25),
        nn.Flatten(),
        nn.Linear(256 * 5 * 5, 1),
        nn.Sigmoid()
    )

    def forward(self, img):
        validity = self.model(img)
        return validity

# %%
generator = Generator(latent_dim).to(device)
discriminator = Discriminator().to(device)

# Loss function
adversarial_loss = nn.BCELoss()

# Optimizers
optimizer_G = optim.Adam(generator.parameters()\
                         , lr=lr, betas=(beta1, beta2))
optimizer_D = optim.Adam(discriminator.parameters()\
                         , lr=lr, betas=(beta1, beta2))

# %%
# Training
# Training loop
for epoch in range(num_epochs):
    for i, batch in enumerate(dataloader):
       # Convert list to tensor
        real_images = batch[0].to(device)
        # Adversarial ground truths
        valid = torch.ones(real_images.size(0), 1, device=device)
        fake = torch.zeros(real_images.size(0), 1, device=device)
        # Configure input
        real_images = real_images.to(device)

        # ---------------------
        #  Train Discriminator
        # ---------------------
        optimizer_D.zero_grad()
        # Sample noise as generator input
        z = torch.randn(real_images.size(0), latent_dim, device=device)
        # Generate a batch of images
        fake_images = generator(z)

        # Measure discriminator's ability
        # to classify real and fake images
        real_loss = adversarial_loss(discriminator\
                                     (real_images), valid)
        fake_loss = adversarial_loss(discriminator\
                                     (fake_images.detach()), fake)
        d_loss = (real_loss + fake_loss) / 2
        # Backward pass and optimize
        d_loss.backward()
        optimizer_D.step()

        # -----------------
        #  Train Generator
        # -----------------

        optimizer_G.zero_grad()
        # Generate a batch of images
        gen_images = generator(z)
        # Adversarial loss
        g_loss = adversarial_loss(discriminator(gen_images), valid)
        # Backward pass and optimize
        g_loss.backward()
        optimizer_G.step()
        # ---------------------
        #  Progress Monitoring
        # ---------------------
        if (i + 1) % 100 == 0:
            print(
                f"Epoch [{epoch+1}/{num_epochs}]\
                        Batch {i+1}/{len(dataloader)} "
                f"Discriminator Loss: {d_loss.item():.4f} "
                f"Generator Loss: {g_loss.item():.4f}"
            )
    # Save generated images for every epoch
    if (epoch + 1) % 10 == 0:
        with torch.no_grad():
            z = torch.randn(16, latent_dim, device=device)
            generated = generator(z).detach().cpu()
            grid = torchvision.utils.make_grid(generated,\
                                        nrow=4, normalize=True)
            plt.imshow(np.transpose(grid, (1, 2, 0)))
            plt.axis("off")
            plt.show()
# Out:
# Epoch [1/10]                        Batch 100/1563 Discriminator Loss: 0.5693 Generator Loss: 1.3841
# Epoch [1/10]                        Batch 200/1563 Discriminator Loss: 0.6534 Generator Loss: 0.9178
# Epoch [1/10]                        Batch 300/1563 Discriminator Loss: 0.5812 Generator Loss: 1.0254
# Epoch [1/10]                        Batch 400/1563 Discriminator Loss: 0.7302 Generator Loss: 1.0898
# Epoch [1/10]                        Batch 500/1563 Discriminator Loss: 0.6607 Generator Loss: 0.8646
# Epoch [1/10]                        Batch 600/1563 Discriminator Loss: 0.6445 Generator Loss: 0.9180
# Epoch [1/10]                        Batch 700/1563 Discriminator Loss: 0.7986 Generator Loss: 0.8648
# Epoch [1/10]                        Batch 800/1563 Discriminator Loss: 0.6419 Generator Loss: 0.9227
# Epoch [1/10]                        Batch 900/1563 Discriminator Loss: 0.6998 Generator Loss: 0.8285
# Epoch [1/10]                        Batch 1000/1563 Discriminator Loss: 0.5121 Generator Loss: 1.0262
# Epoch [1/10]                        Batch 1100/1563 Discriminator Loss: 0.6036 Generator Loss: 1.2411
# Epoch [1/10]                        Batch 1200/1563 Discriminator Loss: 0.7046 Generator Loss: 0.8199
# Epoch [1/10]                        Batch 1300/1563 Discriminator Loss: 0.7127 Generator Loss: 1.1321
# Epoch [1/10]                        Batch 1400/1563 Discriminator Loss: 0.7246 Generator Loss: 1.0392
# Epoch [1/10]                        Batch 1500/1563 Discriminator Loss: 0.6268 Generator Loss: 1.1100
# Epoch [2/10]                        Batch 100/1563 Discriminator Loss: 0.6431 Generator Loss: 0.8922
# Epoch [2/10]                        Batch 200/1563 Discriminator Loss: 0.5280 Generator Loss: 1.4606
# Epoch [2/10]                        Batch 300/1563 Discriminator Loss: 0.6719 Generator Loss: 0.6977
# Epoch [2/10]                        Batch 400/1563 Discriminator Loss: 0.7010 Generator Loss: 0.7955
# Epoch [2/10]                        Batch 500/1563 Discriminator Loss: 0.6693 Generator Loss: 0.8757
# Epoch [2/10]                        Batch 600/1563 Discriminator Loss: 0.6821 Generator Loss: 1.0145
# Epoch [2/10]                        Batch 700/1563 Discriminator Loss: 0.5946 Generator Loss: 0.9580
# Epoch [2/10]                        Batch 800/1563 Discriminator Loss: 0.5751 Generator Loss: 0.9168
# Epoch [2/10]                        Batch 900/1563 Discriminator Loss: 0.6498 Generator Loss: 1.1742
# Epoch [2/10]                        Batch 1000/1563 Discriminator Loss: 0.7745 Generator Loss: 0.7154
# Epoch [2/10]                        Batch 1100/1563 Discriminator Loss: 0.4742 Generator Loss: 1.7340
# Epoch [2/10]                        Batch 1200/1563 Discriminator Loss: 0.5859 Generator Loss: 0.9528
# Epoch [2/10]                        Batch 1300/1563 Discriminator Loss: 0.7329 Generator Loss: 1.1517
# Epoch [2/10]                        Batch 1400/1563 Discriminator Loss: 0.5458 Generator Loss: 1.0642
# Epoch [2/10]                        Batch 1500/1563 Discriminator Loss: 0.6032 Generator Loss: 0.9175
# Epoch [3/10]                        Batch 100/1563 Discriminator Loss: 0.4970 Generator Loss: 1.4292
# Epoch [3/10]                        Batch 200/1563 Discriminator Loss: 0.4284 Generator Loss: 1.7910
# Epoch [3/10]                        Batch 300/1563 Discriminator Loss: 0.6434 Generator Loss: 1.0214
# Epoch [3/10]                        Batch 400/1563 Discriminator Loss: 0.5597 Generator Loss: 1.1621
# Epoch [3/10]                        Batch 500/1563 Discriminator Loss: 0.6077 Generator Loss: 0.8063
# Epoch [3/10]                        Batch 600/1563 Discriminator Loss: 0.6299 Generator Loss: 1.2062
# Epoch [3/10]                        Batch 700/1563 Discriminator Loss: 0.6375 Generator Loss: 1.1305
# Epoch [3/10]                        Batch 800/1563 Discriminator Loss: 0.5150 Generator Loss: 1.1245
# Epoch [3/10]                        Batch 900/1563 Discriminator Loss: 0.4887 Generator Loss: 1.3792
# Epoch [3/10]                        Batch 1000/1563 Discriminator Loss: 0.8544 Generator Loss: 1.1426
# Epoch [3/10]                        Batch 1100/1563 Discriminator Loss: 0.4996 Generator Loss: 1.5230
# Epoch [3/10]                        Batch 1200/1563 Discriminator Loss: 0.6326 Generator Loss: 0.8119
# Epoch [3/10]                        Batch 1300/1563 Discriminator Loss: 0.5563 Generator Loss: 1.1747
# Epoch [3/10]                        Batch 1400/1563 Discriminator Loss: 0.5849 Generator Loss: 1.0508
# Epoch [3/10]                        Batch 1500/1563 Discriminator Loss: 0.5263 Generator Loss: 1.6007
# Epoch [4/10]                        Batch 100/1563 Discriminator Loss: 0.6410 Generator Loss: 1.0530
# Epoch [4/10]                        Batch 200/1563 Discriminator Loss: 0.5372 Generator Loss: 0.9089
# Epoch [4/10]                        Batch 300/1563 Discriminator Loss: 0.6682 Generator Loss: 0.9042
# Epoch [4/10]                        Batch 400/1563 Discriminator Loss: 0.6355 Generator Loss: 0.8696
# Epoch [4/10]                        Batch 500/1563 Discriminator Loss: 0.5454 Generator Loss: 0.7663
# Epoch [4/10]                        Batch 600/1563 Discriminator Loss: 0.4504 Generator Loss: 1.4652
# Epoch [4/10]                        Batch 700/1563 Discriminator Loss: 0.7536 Generator Loss: 0.8766
# Epoch [4/10]                        Batch 800/1563 Discriminator Loss: 0.6066 Generator Loss: 1.1272
# Epoch [4/10]                        Batch 900/1563 Discriminator Loss: 0.6453 Generator Loss: 1.0745
# Epoch [4/10]                        Batch 1000/1563 Discriminator Loss: 0.6828 Generator Loss: 0.7850
# Epoch [4/10]                        Batch 1100/1563 Discriminator Loss: 0.7796 Generator Loss: 1.0649
# Epoch [4/10]                        Batch 1200/1563 Discriminator Loss: 0.6596 Generator Loss: 0.8994
# Epoch [4/10]                        Batch 1300/1563 Discriminator Loss: 0.5357 Generator Loss: 1.1404
# Epoch [4/10]                        Batch 1400/1563 Discriminator Loss: 0.4888 Generator Loss: 1.3187
# Epoch [4/10]                        Batch 1500/1563 Discriminator Loss: 0.7370 Generator Loss: 1.1220
# Epoch [5/10]                        Batch 100/1563 Discriminator Loss: 0.5113 Generator Loss: 1.5162
# Epoch [5/10]                        Batch 200/1563 Discriminator Loss: 0.7967 Generator Loss: 1.0904
# Epoch [5/10]                        Batch 300/1563 Discriminator Loss: 0.6334 Generator Loss: 1.2128
# Epoch [5/10]                        Batch 400/1563 Discriminator Loss: 0.6025 Generator Loss: 1.1540
# Epoch [5/10]                        Batch 500/1563 Discriminator Loss: 0.4903 Generator Loss: 0.9993
# Epoch [5/10]                        Batch 600/1563 Discriminator Loss: 0.6234 Generator Loss: 1.0977
# Epoch [5/10]                        Batch 700/1563 Discriminator Loss: 0.7474 Generator Loss: 0.7718
# Epoch [5/10]                        Batch 800/1563 Discriminator Loss: 0.4435 Generator Loss: 1.2308
# Epoch [5/10]                        Batch 900/1563 Discriminator Loss: 0.7038 Generator Loss: 0.8072
# Epoch [5/10]                        Batch 1000/1563 Discriminator Loss: 0.5149 Generator Loss: 1.5394
# Epoch [5/10]                        Batch 1100/1563 Discriminator Loss: 0.5506 Generator Loss: 1.4319
# Epoch [5/10]                        Batch 1200/1563 Discriminator Loss: 0.5834 Generator Loss: 0.8683
# Epoch [5/10]                        Batch 1300/1563 Discriminator Loss: 0.6526 Generator Loss: 0.9526
# Epoch [5/10]                        Batch 1400/1563 Discriminator Loss: 0.5870 Generator Loss: 1.3532
# Epoch [5/10]                        Batch 1500/1563 Discriminator Loss: 0.4958 Generator Loss: 1.1472
# Epoch [6/10]                        Batch 100/1563 Discriminator Loss: 0.7936 Generator Loss: 1.1357
# Epoch [6/10]                        Batch 200/1563 Discriminator Loss: 0.6855 Generator Loss: 0.8146
# Epoch [6/10]                        Batch 300/1563 Discriminator Loss: 0.6782 Generator Loss: 1.0793
# Epoch [6/10]                        Batch 400/1563 Discriminator Loss: 0.6802 Generator Loss: 0.7589
# Epoch [6/10]                        Batch 500/1563 Discriminator Loss: 0.5531 Generator Loss: 1.7160
# Epoch [6/10]                        Batch 600/1563 Discriminator Loss: 0.6820 Generator Loss: 1.0975
# Epoch [6/10]                        Batch 700/1563 Discriminator Loss: 0.6192 Generator Loss: 1.0333
# Epoch [6/10]                        Batch 800/1563 Discriminator Loss: 0.5458 Generator Loss: 1.7267
# Epoch [6/10]                        Batch 900/1563 Discriminator Loss: 0.5009 Generator Loss: 1.1382
# Epoch [6/10]                        Batch 1000/1563 Discriminator Loss: 0.6576 Generator Loss: 1.2981
# Epoch [6/10]                        Batch 1100/1563 Discriminator Loss: 0.6074 Generator Loss: 0.8359
# Epoch [6/10]                        Batch 1200/1563 Discriminator Loss: 0.6129 Generator Loss: 0.6568
# Epoch [6/10]                        Batch 1300/1563 Discriminator Loss: 0.4895 Generator Loss: 1.2179
# Epoch [6/10]                        Batch 1400/1563 Discriminator Loss: 0.6524 Generator Loss: 1.2510
# Epoch [6/10]                        Batch 1500/1563 Discriminator Loss: 0.5245 Generator Loss: 1.5243
# Epoch [7/10]                        Batch 100/1563 Discriminator Loss: 0.7263 Generator Loss: 1.0599
# Epoch [7/10]                        Batch 200/1563 Discriminator Loss: 0.7250 Generator Loss: 1.1769
# Epoch [7/10]                        Batch 300/1563 Discriminator Loss: 0.5669 Generator Loss: 0.6984
# Epoch [7/10]                        Batch 400/1563 Discriminator Loss: 0.6075 Generator Loss: 1.2513
# Epoch [7/10]                        Batch 500/1563 Discriminator Loss: 0.5028 Generator Loss: 1.2309
# Epoch [7/10]                        Batch 600/1563 Discriminator Loss: 0.9162 Generator Loss: 0.9025
# Epoch [7/10]                        Batch 700/1563 Discriminator Loss: 0.5682 Generator Loss: 1.0064
# Epoch [7/10]                        Batch 800/1563 Discriminator Loss: 0.4751 Generator Loss: 1.7022
# Epoch [7/10]                        Batch 900/1563 Discriminator Loss: 0.7940 Generator Loss: 1.0358
# Epoch [7/10]                        Batch 1000/1563 Discriminator Loss: 0.5269 Generator Loss: 1.2653
# Epoch [7/10]                        Batch 1100/1563 Discriminator Loss: 0.6878 Generator Loss: 1.0632
# Epoch [7/10]                        Batch 1200/1563 Discriminator Loss: 0.6149 Generator Loss: 1.4230
# Epoch [7/10]                        Batch 1300/1563 Discriminator Loss: 0.5108 Generator Loss: 1.4238
# Epoch [7/10]                        Batch 1400/1563 Discriminator Loss: 0.6041 Generator Loss: 1.5479
# Epoch [7/10]                        Batch 1500/1563 Discriminator Loss: 0.6969 Generator Loss: 1.1362
# Epoch [8/10]                        Batch 100/1563 Discriminator Loss: 0.5638 Generator Loss: 1.3723
# Epoch [8/10]                        Batch 200/1563 Discriminator Loss: 0.5044 Generator Loss: 1.3748
# Epoch [8/10]                        Batch 300/1563 Discriminator Loss: 0.4525 Generator Loss: 1.4358
# Epoch [8/10]                        Batch 400/1563 Discriminator Loss: 0.3108 Generator Loss: 2.3137
# Epoch [8/10]                        Batch 500/1563 Discriminator Loss: 0.3583 Generator Loss: 1.5413
# Epoch [8/10]                        Batch 600/1563 Discriminator Loss: 1.2065 Generator Loss: 0.7171
# Epoch [8/10]                        Batch 700/1563 Discriminator Loss: 0.4838 Generator Loss: 1.0454
# Epoch [8/10]                        Batch 800/1563 Discriminator Loss: 0.8510 Generator Loss: 1.2755
# Epoch [8/10]                        Batch 900/1563 Discriminator Loss: 0.4234 Generator Loss: 1.6137
# Epoch [8/10]                        Batch 1000/1563 Discriminator Loss: 0.5652 Generator Loss: 0.9105
# Epoch [8/10]                        Batch 1100/1563 Discriminator Loss: 0.4823 Generator Loss: 1.6639
# Epoch [8/10]                        Batch 1200/1563 Discriminator Loss: 0.2888 Generator Loss: 1.4564
# Epoch [8/10]                        Batch 1300/1563 Discriminator Loss: 0.5051 Generator Loss: 1.4825
# Epoch [8/10]                        Batch 1400/1563 Discriminator Loss: 0.5045 Generator Loss: 1.8468
# Epoch [8/10]                        Batch 1500/1563 Discriminator Loss: 0.4057 Generator Loss: 1.4963
# Epoch [9/10]                        Batch 100/1563 Discriminator Loss: 0.5494 Generator Loss: 1.5183
# Epoch [9/10]                        Batch 200/1563 Discriminator Loss: 0.5760 Generator Loss: 0.9807
# Epoch [9/10]                        Batch 300/1563 Discriminator Loss: 0.6980 Generator Loss: 1.6098
# Epoch [9/10]                        Batch 400/1563 Discriminator Loss: 0.7233 Generator Loss: 1.2764
# Epoch [9/10]                        Batch 500/1563 Discriminator Loss: 0.8189 Generator Loss: 1.9684
# Epoch [9/10]                        Batch 600/1563 Discriminator Loss: 0.5976 Generator Loss: 0.6833
# Epoch [9/10]                        Batch 700/1563 Discriminator Loss: 0.5912 Generator Loss: 0.9759
# Epoch [9/10]                        Batch 800/1563 Discriminator Loss: 0.5668 Generator Loss: 2.0986
# Epoch [9/10]                        Batch 900/1563 Discriminator Loss: 0.4502 Generator Loss: 1.2321
# Epoch [9/10]                        Batch 1000/1563 Discriminator Loss: 0.5131 Generator Loss: 2.2117
# Epoch [9/10]                        Batch 1100/1563 Discriminator Loss: 0.6272 Generator Loss: 0.9084
# Epoch [9/10]                        Batch 1200/1563 Discriminator Loss: 0.9006 Generator Loss: 0.9243
# Epoch [9/10]                        Batch 1300/1563 Discriminator Loss: 0.3343 Generator Loss: 1.4476
# Epoch [9/10]                        Batch 1400/1563 Discriminator Loss: 0.4578 Generator Loss: 1.0603
# Epoch [9/10]                        Batch 1500/1563 Discriminator Loss: 0.8658 Generator Loss: 0.3156
# Epoch [10/10]                        Batch 100/1563 Discriminator Loss: 0.5027 Generator Loss: 1.1279
# Epoch [10/10]                        Batch 200/1563 Discriminator Loss: 0.5222 Generator Loss: 0.8799
# Epoch [10/10]                        Batch 300/1563 Discriminator Loss: 0.7008 Generator Loss: 0.8115
# Epoch [10/10]                        Batch 400/1563 Discriminator Loss: 0.6440 Generator Loss: 1.5768
# Epoch [10/10]                        Batch 500/1563 Discriminator Loss: 0.6119 Generator Loss: 1.0344
# Epoch [10/10]                        Batch 600/1563 Discriminator Loss: 0.4756 Generator Loss: 0.8287
# Epoch [10/10]                        Batch 700/1563 Discriminator Loss: 0.2945 Generator Loss: 1.8823
# Epoch [10/10]                        Batch 800/1563 Discriminator Loss: 0.4653 Generator Loss: 2.1382
# Epoch [10/10]                        Batch 900/1563 Discriminator Loss: 1.0193 Generator Loss: 1.4222
# Epoch [10/10]                        Batch 1000/1563 Discriminator Loss: 0.2696 Generator Loss: 1.2747
# Epoch [10/10]                        Batch 1100/1563 Discriminator Loss: 0.5917 Generator Loss: 1.0896
# Epoch [10/10]                        Batch 1200/1563 Discriminator Loss: 0.6127 Generator Loss: 1.0731
# Epoch [10/10]                        Batch 1300/1563 Discriminator Loss: 0.8898 Generator Loss: 0.5669
# Epoch [10/10]                        Batch 1400/1563 Discriminator Loss: 0.7064 Generator Loss: 2.0093
# Epoch [10/10]                        Batch 1500/1563 Discriminator Loss: 0.5836 Generator Loss: 1.5197
